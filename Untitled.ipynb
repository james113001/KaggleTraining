# %%
import pandas as pd
import os
import ffmpeg
import bar_chart_race as bcr

# %%
df = pd.read_csv("Video_Games.csv")

# %%
df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# ...

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
sales = df.iloc[:, [0,1,2,9]]

# %%
sales.isna().sum()
# Out:
# Name                 2
# Platform             0
# Year_of_Release    269
# Global_Sales         0
# dtype: int64

# %%
yearless=sales.loc[sales['Year_of_Release'].isna() == True]
hasyear=sales.notna()

# %%
hasyear.describe()
# Out:
#          Name Platform Year_of_Release Global_Sales
# count   16719    16719           16719        16719
# unique      2        1               2            1
# top      True     True            True         True
# freq    16717    16719           16450        16719

# %%
print(yearless.iloc[:,0:2].values)
# Out:
# [['Madden NFL 2004' 'PS2']
#  ['FIFA Soccer 2004' 'PS2']
#  ['LEGO Batman: The Videogame' 'Wii']
#  ['wwe Smackdown vs. Raw 2006' 'PS2']
#  ['Space Invaders' '2600']
#  ['Rock Band' 'X360']
#  ["Frogger's Adventures: Temple of the Frog" 'GBA']
#  ['LEGO Indiana Jones: The Original Adventures' 'Wii']
#  ['Call of Duty 3' 'Wii']
#  ['Rock Band' 'Wii']
#  ['Call of Duty: Black Ops' 'PC']
#  ['Rock Band' 'PS3']
#  ['Triple Play 99' 'PS']
#  ['Adventure' '2600']
#  ['LEGO Batman: The Videogame' 'PSP']
#  ['Combat' '2600']
#  ['LEGO Harry Potter: Years 5-7' 'Wii']
#  ['NASCAR Thunder 2003' 'PS2']
#  ['Hitman 2: Silent Assassin' 'XB']
#  ['Rock Band' 'PS2']
#  ['Legacy of Kain: Soul Reaver' 'PS']
#  ['Donkey Kong Land III' 'GB']
#  ['Air-Sea Battle' '2600']
#  ['Suikoden III' 'PS2']
#  ['LEGO Harry Potter: Years 5-7' 'X360']
#  ['Wheel of Fortune' 'PS2']
#  ['Yakuza 4' 'PS3']
#  ['LEGO Harry Potter: Years 5-7' 'PS3']
#  ['Namco Museum' 'XB']
#  ['Rhythm Heaven' 'Wii']
# ...

# %%
sales
# Out:
#                                 Name Platform  Year_of_Release  Global_Sales
# 0                         Wii Sports      Wii           2006.0         82.53
# 1                  Super Mario Bros.      NES           1985.0         40.24
# 2                     Mario Kart Wii      Wii           2008.0         35.52
# 3                  Wii Sports Resort      Wii           2009.0         32.77
# 4           Pokemon Red/Pokemon Blue       GB           1996.0         31.37
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0          0.01
# 16715               LMA Manager 2007     X360           2006.0          0.01
# 16716        Haitaka no Psychedelica      PSV           2016.0          0.01
# 16717               Spirits & Spells      GBA           2003.0          0.01
# 16718            Winning Post 8 2016      PSV           2016.0          0.01
#
# [16719 rows x 4 columns]

# %%
sales['Rank'] = sales['Global_Sales'].rank()
# Out:
# C:\Users\JKim\AppData\Local\Temp\ipykernel_10620\2813278350.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['Rank'] = sales['Global_Sales'].rank()

# %%
sales = sales.sort_values(by='Global_Sales', ascending=False)
sales
# Out:
#                                                     Name Platform  \
# 0                                             Wii Sports      Wii
# 1                                      Super Mario Bros.      NES
# 2                                         Mario Kart Wii      Wii
# 3                                      Wii Sports Resort      Wii
# 4                               Pokemon Red/Pokemon Blue       GB
# ...                                                  ...      ...
# 16294  Simple 2000 Series Vol. 120: The Saigo no Nipp...      PS2
# 16295                                             Casper      GBA
# 16296             AKB1/48: Idol to Guam de Koishitara...     X360
# 16297        Adventure Time: The Secret of the Nameless      X360
# 16718                                Winning Post 8 2016      PSV
#
#        Year_of_Release  Global_Sales     Rank
# 0               2006.0         82.53  16719.0
# 1               1985.0         40.24  16718.0
# ...

# %%
sales.set_index('Year_of_Release', inplace = True)

# %%
bcr.bar_chart_race(df=sales,filename=None,title= "Global Top-Selling Videogames by Year")
# Out:
# C:\Users\JKim\AppData\Local\anaconda3\Lib\site-packages\bar_chart_race\_make_chart.py:893: FutureWarning: Dropping of nuisance columns in DataFrame.rank is deprecated; in a future version this will raise TypeError. Select only valid columns before calling rank.
#   df_ranks = df_values.rank(axis=1, method='first', ascending=False).clip(upper=n_bars + 1)
# C:\Users\JKim\AppData\Local\anaconda3\Lib\site-packages\bar_chart_race\_make_chart.py:278: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   max_val = self.df_values.max().max()
# C:\Users\JKim\AppData\Local\anaconda3\Lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# ...
