# %%
from pathlib import Path
import pandas as pd
# import seaborn as sns

# preprocessing / pipeline
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# clfs
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.dummy import DummyClassifier

# cross_validation
from sklearn.experimental import enable_halving_search_cv # noqa
from sklearn.model_selection import RepeatedStratifiedKFold, HalvingGridSearchCV

# %% [markdown]
# ## IO

# %%
DATA_DIR = Path("../data/processed/")
train = pd.read_csv(DATA_DIR / "final_train.csv")
X, y = train.drop(columns='Survived'), train['Survived']

# %%
train['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# ## ML pipeline

# %%
ct = ColumnTransformer(
    transformers=[("numeric", StandardScaler(), ['Age', 'Fare']),
                 ], remainder='passthrough'
)

model = Pipeline(
    steps=[
        ("ct", ct),
        ("clf", DummyClassifier(strategy='constant', constant=1))
    ]
)

# %%
model.fit(X, y)
# Out:
# Pipeline(steps=[('ct',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('numeric', StandardScaler(),
#                                                   ['Age', 'Fare'])])),
#                 ('clf', DummyClassifier(constant=1, strategy='constant'))])

# %% [markdown]
# ## Hyperparameter tuning
#
# - just using classifier parameters but all components of a pipeline can be part of this

# %%
clfs = [
    {'clf': (LogisticRegression(), ), # convention list of tuples for each
     'clf__C': (1,5,10)},
    {'clf' : (DecisionTreeClassifier(), ),
     'clf__max_depth': (1,3,5)},
    {'clf': (RandomForestClassifier(), ),
     'clf__max_depth': (1,3,5)}
]

# %%
# cross validation strategy 
cv = RepeatedStratifiedKFold(n_repeats=3, 
                             n_splits=3,
                             random_state=42) # seed required
# Search strategy
grid = HalvingGridSearchCV(estimator=model,
                           param_grid=clfs,
                           cv=cv)

# %%
grid.fit(X,y)
# Out:
# HalvingGridSearchCV(cv=RepeatedStratifiedKFold(n_repeats=3, n_splits=3, random_state=42),
#                     estimator=Pipeline(steps=[('ct',
#                                                ColumnTransformer(remainder='passthrough',
#                                                                  transformers=[('numeric',
#                                                                                 StandardScaler(),
#                                                                                 ['Age',
#                                                                                  'Fare'])])),
#                                               ('clf',
#                                                DummyClassifier(constant=1,
#                                                                strategy='constant'))]),
#                     param_grid=[{'clf': (LogisticRegression(),),
#                                  'clf__C': (1, 5, 10)},
#                                 {'clf': (DecisionTreeClassifier(max_depth=3),),
#                                  'clf__max_depth': (1, 3, 5)},
#                                 {'clf': (RandomForestClassifier(),),
#                                  'clf__max_depth': (1, 3, 5)}])

# %% [markdown]
# ## Results
#
# - eval scores both test and train are available; good for checking model generalisation to unseen data

# %%
cv_results = pd.DataFrame(grid.cv_results_).sort_values(by='mean_test_score', 
                                                        ascending=False)

# %%
cv_results.head().T
# Out:
#                                                                       7  \
# iter                                                                  0
# n_resources                                                          99
# mean_fit_time                                                  0.134224
# std_fit_time                                                   0.009039
# mean_score_time                                                0.014074
# std_score_time                                                 0.000936
# param_clf                                      RandomForestClassifier()
# param_clf__C                                                        NaN
# param_clf__max_depth                                                  3
# params                {'clf': RandomForestClassifier(), 'clf__max_de...
# split0_test_score                                              0.818182
# split1_test_score                                              0.818182
# split2_test_score                                              0.818182
# split3_test_score                                              0.818182
# split4_test_score                                              0.818182
# split5_test_score                                              0.818182
# split6_test_score                                              0.848485
# split7_test_score                                              0.909091
# split8_test_score                                              0.818182
# mean_test_score                                                 0.83165
# std_test_score                                                 0.028964
# rank_test_score                                                       1
# split0_train_score                                             0.863636
# split1_train_score                                             0.848485
# split2_train_score                                             0.939394
# split3_train_score                                             0.878788
# split4_train_score                                             0.924242
# split5_train_score                                             0.878788
# split6_train_score                                             0.878788
# split7_train_score                                             0.878788
# split8_train_score                                             0.893939
# mean_train_score                                               0.887205
# std_train_score                                                0.026831
#
#                                                                       3  \
# iter                                                                  0
# n_resources                                                          99
# mean_fit_time                                                  0.004294
# std_fit_time                                                   0.000419
# mean_score_time                                                0.002881
# std_score_time                                                 0.000368
# param_clf                           DecisionTreeClassifier(max_depth=3)
# param_clf__C                                                        NaN
# param_clf__max_depth                                                  1
# params                {'clf': DecisionTreeClassifier(max_depth=3), '...
# split0_test_score                                              0.818182
# split1_test_score                                              0.787879
# split2_test_score                                              0.818182
# split3_test_score                                              0.909091
# split4_test_score                                              0.818182
# split5_test_score                                              0.818182
# split6_test_score                                              0.818182
# split7_test_score                                              0.878788
# split8_test_score                                              0.787879
# mean_test_score                                                0.828283
# std_test_score                                                 0.037795
# rank_test_score                                                       2
# split0_train_score                                             0.757576
# split1_train_score                                             0.787879
# split2_train_score                                              0.80303
# split3_train_score                                              0.80303
# split4_train_score                                             0.878788
# split5_train_score                                              0.80303
# split6_train_score                                              0.80303
# split7_train_score                                             0.818182
# split8_train_score                                              0.80303
# mean_train_score                                               0.806397
# std_train_score                                                0.030115
#
#                                                                       4  \
# iter                                                                  0
# n_resources                                                          99
# mean_fit_time                                                  0.004706
# std_fit_time                                                   0.000644
# mean_score_time                                                0.002989
# std_score_time                                                 0.000815
# param_clf                           DecisionTreeClassifier(max_depth=3)
# param_clf__C                                                        NaN
# param_clf__max_depth                                                  3
# params                {'clf': DecisionTreeClassifier(max_depth=3), '...
# split0_test_score                                              0.787879
# split1_test_score                                              0.818182
# split2_test_score                                              0.909091
# split3_test_score                                              0.848485
# split4_test_score                                              0.757576
# split5_test_score                                              0.848485
# split6_test_score                                              0.727273
# split7_test_score                                              0.848485
# split8_test_score                                              0.848485
# mean_test_score                                                0.821549
# std_test_score                                                 0.052378
# rank_test_score                                                       3
# split0_train_score                                             0.893939
# split1_train_score                                             0.878788
# split2_train_score                                             0.924242
# split3_train_score                                             0.878788
# split4_train_score                                             0.909091
# split5_train_score                                             0.848485
# split6_train_score                                             0.909091
# split7_train_score                                             0.878788
# split8_train_score                                             0.893939
# mean_train_score                                               0.890572
# std_train_score                                                0.021161
#
#                                                                0  \
# iter                                                           0
# n_resources                                                   99
# mean_fit_time                                           0.008841
# std_fit_time                                            0.001618
# mean_score_time                                          0.00351
# std_score_time                                          0.000485
# param_clf                                   LogisticRegression()
# param_clf__C                                                   1
# param_clf__max_depth                                         NaN
# params                {'clf': LogisticRegression(), 'clf__C': 1}
# split0_test_score                                       0.787879
# split1_test_score                                       0.818182
# split2_test_score                                       0.818182
# split3_test_score                                       0.818182
# split4_test_score                                       0.818182
# split5_test_score                                       0.818182
# split6_test_score                                       0.848485
# split7_test_score                                       0.878788
# split8_test_score                                       0.757576
# mean_test_score                                         0.818182
# std_test_score                                          0.031942
# rank_test_score                                                4
# split0_train_score                                      0.787879
# split1_train_score                                      0.848485
# split2_train_score                                      0.893939
# split3_train_score                                      0.833333
# split4_train_score                                      0.878788
# split5_train_score                                      0.818182
# split6_train_score                                      0.772727
# split7_train_score                                      0.818182
# split8_train_score                                      0.787879
# mean_train_score                                        0.826599
# std_train_score                                         0.039193
#
#                                                                1
# iter                                                           0
# n_resources                                                   99
# mean_fit_time                                           0.008976
# std_fit_time                                            0.000911
# mean_score_time                                         0.003442
# std_score_time                                          0.000483
# param_clf                                   LogisticRegression()
# param_clf__C                                                   5
# param_clf__max_depth                                         NaN
# params                {'clf': LogisticRegression(), 'clf__C': 5}
# split0_test_score                                       0.787879
# split1_test_score                                       0.848485
# split2_test_score                                       0.848485
# split3_test_score                                       0.848485
# split4_test_score                                       0.818182
# split5_test_score                                       0.787879
# split6_test_score                                       0.787879
# split7_test_score                                       0.848485
# split8_test_score                                       0.757576
# mean_test_score                                         0.814815
# std_test_score                                          0.033332
# rank_test_score                                                5
# split0_train_score                                      0.848485
# split1_train_score                                      0.863636
# split2_train_score                                      0.909091
# split3_train_score                                      0.863636
# split4_train_score                                      0.878788
# split5_train_score                                       0.80303
# split6_train_score                                      0.833333
# split7_train_score                                      0.833333
# split8_train_score                                      0.787879
# mean_train_score                                        0.846801
# std_train_score                                         0.035313

# %% [markdown]
# ## Retrieve params

# %%
grid.best_estimator_
# Out:
# Pipeline(steps=[('ct',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('numeric', StandardScaler(),
#                                                   ['Age', 'Fare'])])),
#                 ('clf', DecisionTreeClassifier(max_depth=3))])

# %%
grid.best_params_
# Out:
# {'clf': DecisionTreeClassifier(max_depth=3), 'clf__max_depth': 3}

# %%
# or if the def of "best" varies you can pull any params from cv_results
best_params = cv_results.query("rank_test_score == 1")['params'].values[0] 
best_params
# Out:
# {'clf': RandomForestClassifier(max_depth=3), 'clf__max_depth': 3}

# %%
model.set_params(**best_params)
# Out:
# Pipeline(steps=[('ct',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('numeric', StandardScaler(),
#                                                   ['Age', 'Fare'])])),
#                 ('clf', RandomForestClassifier(max_depth=3))])

# %% [markdown]
# ## Predict unseen data

# %%
X_test = pd.read_csv(DATA_DIR / "final_test.csv")
# X, y = train.drop(columns='Survived'), train['Survived']

# %%
y_pred = grid.best_estimator_.predict(X_test.drop(columns='PassengerId'))
pd.Series(data= y_pred, 
          index=X_test['PassengerId'])
# Out:
# PassengerId
# 892     0
# 893     1
# 894     0
# 895     0
# 896     1
#        ..
# 1305    0
# 1306    1
# 1307    0
# 1308    0
# 1309    0
# Length: 418, dtype: int64
